# %%
import json

from kafka import KafkaConsumer

# %% [markdown]
# ### Configuration Parameters
#
# > **TODO:** Change the configuration prameters to the appropriate values for your setup.

# %%
config = dict(
    bootstrap_servers=['kafka.kafka.svc.cluster.local:9092'],
    first_name='Kyle',
    last_name='Morris'
)

config['client_id'] = '{}{}'.format(
    config['last_name'], 
    config['first_name']
)
config['topic_prefix'] = '{}{}'.format(
    config['last_name'], 
    config['first_name']
)

config
# Out:
# {'bootstrap_servers': ['kafka.kafka.svc.cluster.local:9092'],
#  'first_name': 'Kyle',
#  'last_name': 'Morris',
#  'client_id': 'MorrisKyle',
#  'topic_prefix': 'MorrisKyle'}

# %% [markdown]
# Create a consumer without subscribing to any particular topic

# %%
general_consumer = KafkaConsumer(
    bootstrap_servers=config['bootstrap_servers']
)

# %% [markdown]
# List all topics you are currently allowed to view

# %%
general_consumer.topics()
# Out:
# {'AndersonChristopher-joined',
#  'AndersonChristopher-locations',
#  'AndersonChristopher-simple',
#  'AndersonChristopher-windowed',
#  'BradwayChristopher-locations',
#  'CherubinFrenel-locations',
#  'DoeJohn-accelerations',
#  'DoeJohn-joined',
#  'DoeJohn-locations',
#  'DoeJohn-simple',
#  'DoeJohn-windowed',
#  'FrenelCherubin-locations',
#  'GoodwinChris-accelerations',
#  'GoodwinChris-locations',
#  'GoodwinChris-simple',
#  'HermansShawn-locations',
#  'Malagon-CorderoAmbrose-windowed',
#  'Malagon_CorderoAmbrose-_accelerations',
#  'Malagon_CorderoAmbrose-_locations',
#  'Malagon_CorderoAmbrose-accelerations',
#  'Malagon_CorderoAmbrose-accelerations1',
#  'Malagon_CorderoAmbrose-accelerations_',
#  'Malagon_CorderoAmbrose-accelerations_1',
#  'Malagon_CorderoAmbrose-accelerations_2',
#  'Malagon_CorderoAmbrose-joined',
#  'Malagon_CorderoAmbrose-locations',
#  'Malagon_CorderoAmbrose-locations1',
#  'Malagon_CorderoAmbrose-locations_',
#  'Malagon_CorderoAmbrose-locations_1',
#  'Malagon_CorderoAmbrose-locations_2',
#  'Malagon_CorderoAmbrose-simple',
#  'Malagon_CorderoAmbrose-windowed',
#  'Manthani2Sathish-simple',
#  'Manthani2Sathish-windowed',
#  'ManthaniSathish-accelerations',
#  'ManthaniSathish-joined',
#  'ManthaniSathish-locations',
#  'ManthaniSathish-simple',
#  'ManthaniSathish-windowed',
#  'MarcumDoug-accelerations',
#  'MarcumDoug-accelerations_1',
#  'MarcumDoug-accelerations_2',
#  'MarcumDoug-accelerations_3',
#  'MarcumDoug-joined',
#  'MarcumDoug-joined_1',
#  'MarcumDoug-locations',
#  'MarcumDoug-locations_1',
#  'MarcumDoug-locations_2',
#  'MarcumDoug-locations_3',
#  'MarcumDoug-simple',
#  'MarcumDoug-simple_1',
#  'MarcumDoug-windowed',
#  'MarcumDoug-windowed_1',
#  'MayBrandon-accelerations1',
#  'MayBrandon-accelerations_1',
#  'MayBrandon-joined',
#  'MayBrandon-locations',
#  'MayBrandon-locations1',
#  'MayBrandon-locations2',
#  'MayBrandon-locations_1',
#  'MayBrandon-simple',
#  'MayBrandon-simple1',
#  'MeyerApril-acceleration',
#  'MeyerApril-joined',
#  'MeyerApril-locations',
#  'MeyerApril-simple',
#  'MeyerApril-windowed',
#  'MorrisKyle-accelerations',
#  'MorrisKyle-joined',
#  'MorrisKyle-locations',
#  'MorrisKyle-simple',
#  'MorrisKyle-windowed',
#  'RautSaroj-joined',
#  'RautSaroj-locations',
#  'RautSaroj-simple',
#  'RautSaroj-windowed',
#  'SalisburyNick-accelerations',
#  'SalisburyNick-joined',
#  'SalisburyNick-locations',
#  'SalisburyNick-simple',
#  'SalisburyNick-windowed',
#  'SamsBrandon-accelerations',
#  'SamsBrandon-locations',
#  'SamsBrandon-simple',
#  'SamsBrandon-windowed',
#  'ShawnHermans-accelerations',
#  'ShawnHermans-joined',
#  'ShawnHermans-locations',
#  'ShawnHermans-simple',
#  'ShawnHermans-windowed',
#  'ValenzuelaGabriel-locations',
#  'WadeSoukhna-joined',
#  'WadeSoukhna-locations',
#  'WadeSoukhna-simple',
#  'WadeSoukhna-windowed',
#  'WellawalageDasun-accelerations',
#  'WellawalageDasun-joined',
#  'WellawalageDasun-locations',
#  'WellawalageDasun-simple',
#  'WellawalageDasun-windowed',
#  'ameyer89-locations',
#  'amon_reversed',
#  'morrisKyle-accelerations',
#  'morrisKyle-location',
#  'morrisKyle-locations',
#  'test',
#  'test_ammc1',
#  'test_ammc2',
#  'testing123'}

# %% [markdown]
# Close the consumer, waiting indefinitely for any needed cleanup.

# %%
general_consumer.close()

# %%
def create_kafka_consumer(topics, config=config):
    bootstrap_servers = config['bootstrap_servers']
    client_id = config['client_id']
    topic_prefix = config['topic_prefix']    
    topic_list = ['{}-{}'.format(topic_prefix, topic) for topic in topics]
    
    return KafkaConsumer(
        *topic_list,
        client_id=client_id,
        bootstrap_servers=bootstrap_servers,
        auto_offset_reset='earliest',
        enable_auto_commit=False,
        value_deserializer=lambda x: json.loads(x)
    )

consumer = create_kafka_consumer(['locations', 'accelerations'])

# %% [markdown]
# Gets a list of this consumer's current subscriptions

# %%
consumer.subscription()
# Out:
# {'MorrisKyle-accelerations', 'MorrisKyle-locations'}

# %% [markdown]
# The following function prints messages from the current consumer subscriptions. It will continue until manually stopped.

# %%
def print_messages(consumer=consumer):
    try:
        for message in consumer:
                msg_metadata = 'Message metadata: {}:{}:{}'.format(
                    message.topic, message.partition, message.offset
                )

                if message.key is not None:
                    msg_key = message.key.decode('utf-8')
                else:
                    msg_key = ''
                msg_value = json.dumps(message.value, indent=2)
                msg_value = '\n'.join(['  {}'.format(value) for value in msg_value.split('\n')])

                print('Message metadata:')
                print('  Topic: {}'.format(message.topic))
                print('  Partition: {}'.format(message.partition))
                print('  Offset: {}'.format(message.offset))
                print('Message Key: {}'.format(msg_key))
                print('Message Value:')
                print(msg_value)
                print()
    except KeyboardInterrupt:
        print("STOPPING MESSAGE CONSUMER")
        
print_messages()
# Out:
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 
# Message Value:
#   {
#     "id": null,
#     "ride_id": "53a79e2d25ebf0ea29b4f4dea39496b3",
#     "uuid": "080ab7e8d1bb4ac4bcf6b32bec82607d",
#     "timestamp": "1970-01-01 00:24:50.366753",
#     "offset": 50.02312381072749,
#     "course": 84.7265625,
#     "latitude": 40.626518600658166,
#     "longitude": -73.97135697312092,
#     "geohash": "dr5rhezdw7yr",
#     "speed": 6.980000019073486,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "b0c74075-f0c0-470a-a2bf-c627f91b30b6.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 1819
# Message Key: b9089ee635584f6abdd04f1a67408f77
# Message Value:
#   {
#     "id": null,
#     "ride_id": "c90bf06d657402ff2aa78e946a1bf990",
#     "uuid": "0cf91dfa92d5497cacef01408913d9a0",
#     "timestamp": "1970-01-01 00:24:50.504243",
#     "offset": 49.91972155699499,
#     "course": 299.1028747558594,
#     "latitude": 40.68926883438216,
#     "longitude": -73.72134313674339,
#     "geohash": "dr5x6rmb0jqq",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "4ed5dc9e-f875-4df7-92d7-123d5e44f958.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 1820
# Message Key: 9e0bf56d4d844a2581a4a5a0b616d449
# Message Value:
#   {
#     "id": "f3134b3497ad6a52204ba8419d9000c5",
#     "ride_id": "4611efd78aae450b1a506d67c4b71c17",
#     "uuid": "9c8f3a88bdab444c92a4c7aab083704a",
#     "timestamp": "1970-01-01 00:25:03.758611",
#     "offset": 50.09028348917131,
#     "course": 118.40481567382812,
#     "latitude": 40.74805959659953,
#     "longitude": -73.99911053065252,
#     "geohash": "dr5ru1gqxszg",
#     "speed": 5.869999885559082,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "be49d159-d750-4191-aba8-fa72218a78ca.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 1821
# Message Key: 12aba21221d14e30b91017cbc543953c
# Message Value:
#   {
#     "id": null,
#     "ride_id": "582d3e7fa3cc301af55d6cb6bf20de0c",
#     "uuid": "35a1f553cfa849bbaec122df745c9457",
#     "timestamp": "1970-01-01 00:24:50.662690",
#     "offset": 49.81298862018564,
#     "course": 192.83502197265625,
#     "latitude": 40.74683935992357,
#     "longitude": -74.03183585251338,
#     "geohash": "dr5rg3ext1qh",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "e9ac52ac-7ccd-48a5-af60-7bdd8c53ac9f.mov"
#   }
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 1822
# Message Key: fd16a08bcf574754bd3c66c55ebaf765
# Message Value:
#   {
#     "id": "723d9d0fa092b5ca1ffce252012836de",
#     "ride_id": "4f9ca8ae06a03858267820b3ad458fce",
#     "uuid": "459eeb9143d04df3b27397678047be20",
#     "timestamp": "1970-01-01 00:25:04.355826",
#     "offset": 50.14024503805739,
#     "course": 113.203125,
#     "latitude": 40.87412919852964,
#     "longitude": -73.8563586027118,
#     "geohash": "dr72x2gmn1gq",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "78665bfb-b7d8-464a-a840-8a967d44e187.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 1823
# Message Key: a3f7a08bde374b578be9823ee1e81ca4
# Message Value:
#   {
#     "id": "3b4793accf1f5feb077f7c8e097642a7",
#     "ride_id": "5205b643b19fddd587541333533b2d4a",
#     "uuid": "f547f4bf60cb40d3a86e00412d076e18",
#     "timestamp": "1970-01-01 00:25:07.471334",
#     "offset": 49.64691734364177,
#     "course": 218.3203125,
#     "latitude": 40.6138375355309,
#     "longitude": -73.98511720828151,
#     "geohash": "dr5rh3t8vb41",
#     "speed": 13.630000114440918,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "3fd49753-bc3e-401c-8511-bcb79223cc6b.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 1824
# Message Key: a129d58993e94d39bf532b43eae6e336
# Message Value:
#   {
#     "id": null,
#     "ride_id": "b1df722f6aa469b416e6abb65c5f7fc4",
#     "uuid": "04661f25e6354f5b92284e804a97db95",
#     "timestamp": "1970-01-01 00:24:50.304814",
#     "offset": 50.243265911965004,
#     "course": 184.5703125,
#     "latitude": 37.6776097063326,
#     "longitude": -122.3885714729525,
#     "geohash": "9q8yqfzrgxd8",
#     "speed": 30.34000015258789,
#     "accuracy": 5.0,
#     "timelapse": "False",
#     "filename": "57d21f3f-97c6-45b1-89f8-8ddc0ce78b48.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 1825
# Message Key: 7cdb55fabb6d44a98db82ac941b7320d
# Message Value:
#   {
#     "id": null,
#     "ride_id": "582c5336938f138cf286af1adc12e3b3",
#     "uuid": "88005d17b10e4fcb8dec1cff5627ad39",
#     "timestamp": "1970-01-01 00:24:50.293780",
#     "offset": 50.41138790226977,
#     "course": 27.421875,
#     "latitude": 40.77500833202225,
#     "longitude": -73.97684678442215,
#     "geohash": "dr5ruwgews2z",
#     "speed": 4.0,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "a96b2581-610e-441f-9fdd-ed004ba41d27.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1843
# Message Key: 812cce5eab6c4cd9a78598cde9b94b1e
# Message Value:
#   {
#     "id": "097ec0c2d59a23b76b4942bd8d9a7a77",
#     "ride_id": "9cd83b5a569a73d2e596888b6a6ad6ad",
#     "uuid": "a8fab740fe074ef1acc7d4c940398ce8",
#     "timestamp": "1970-01-01 00:25:04.070064",
#     "offset": 49.47229633059419,
#     "x": 1.043,
#     "y": -0.094,
#     "z": 0.14300000000000002,
#     "timelapse": "False",
#     "filename": "65c58848-8a31-4b1c-bfef-8643378fec25.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1844
# Message Key: 1244e384c06a4ad6a2810a3fcc94b44f
# Message Value:
#   {
#     "id": "6edc87cd82b135715d4581c2505ef753",
#     "ride_id": "a19ba1f168154326694b7dbc2209518f",
#     "uuid": "1bb324e027224f769047ac3a76afeb5c",
#     "timestamp": "1970-01-01 00:25:04.016747",
#     "offset": 49.47848352122478,
#     "x": -1.008,
#     "y": 0.006,
#     "z": 0.032,
#     "timelapse": "False",
#     "filename": "517b138f-a10d-4a8a-8d8a-312d5140669d.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1845
# Message Key: daee881238ae4cacadd5cf4dc5a66d28
# Message Value:
#   {
#     "id": null,
#     "ride_id": "39805d0846324773acf22971bcffa7ac",
#     "uuid": "09eeae24d6d446d0bbbeb994d6c6a13f",
#     "timestamp": "1970-01-01 00:24:49.619754",
#     "offset": 49.476409285980004,
#     "x": 1.0050000000000001,
#     "y": 0.058,
#     "z": 0.021,
#     "timelapse": "False",
#     "filename": "55e66eff-1ca8-47dc-bd29-289a9d332c6f.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1846
# Message Key: c39f68cc17fa4234b67b360eb2adb8a3
# Message Value:
#   {
#     "id": "759e4b98ce8cfadd1004453cb2107436",
#     "ride_id": "91126a54bb966b38f64c62aded306c37",
#     "uuid": "2cc21cea5b534b59b596172f8dacbe5b",
#     "timestamp": "1970-01-01 00:25:03.714299",
#     "offset": 49.48219548560322,
#     "x": 0.98,
#     "y": 0.011,
#     "z": -0.008,
#     "timelapse": "False",
#     "filename": "891d1bd9-2ded-442c-8111-5f2692f3928c.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1847
# Message Key: 95c91a5c4aef4f179a7a563509fc81a3
# Message Value:
#   {
#     "id": "c44516bd325cb60548b431b4d6409dde",
#     "ride_id": "b063cb65cd8446b83b4a09d4db2646c8",
#     "uuid": "c6608d4cb9224aa3a0763a835e6c8788",
#     "timestamp": "1970-01-01 00:25:06.796332",
#     "offset": 49.4667702566351,
#     "x": -1.018,
#     "y": 0.017,
#     "z": 0.17400000000000002,
#     "timelapse": "False",
#     "filename": "0d4d27dc-360b-4bb2-9b0c-bf84be964785.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1848
# Message Key: 3518a9c65059442d9acc9fbe44a6a1e2
# Message Value:
#   {
#     "id": "0a89528a4445884f061ffce814b59455",
#     "ride_id": "353c68ef278055e9a1ec28a3dd0cf9e8",
#     "uuid": "7755cb5919884b8eabd707a743f29c0c",
#     "timestamp": "1970-01-01 00:25:04.219575",
#     "offset": 50.53635446777489,
#     "x": -0.713,
#     "y": -0.226,
#     "z": 0.022,
#     "timelapse": "False",
#     "filename": "c23afa84-4ea7-4d77-8da5-48eb38b3fcd6.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1849
# Message Key: 779a00d9c91c405fa3879bf9e26dd1f3
# Message Value:
#   {
#     "id": null,
#     "ride_id": "53a79e2d25ebf0ea29b4f4dea39496b3",
#     "uuid": "080ab7e8d1bb4ac4bcf6b32bec82607d",
#     "timestamp": "1970-01-01 00:24:50.366753",
#     "offset": 49.48312381072749,
#     "x": -0.918,
#     "y": 0.034,
#     "z": -0.099,
#     "timelapse": "False",
#     "filename": "b0c74075-f0c0-470a-a2bf-c627f91b30b6.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1850
# Message Key: 99646c282e0d48d38d7d4fd56b2a5f85
# Message Value:
#   {
#     "id": null,
#     "ride_id": "c90bf06d657402ff2aa78e946a1bf990",
#     "uuid": "0cf91dfa92d5497cacef01408913d9a0",
#     "timestamp": "1970-01-01 00:24:50.504243",
#     "offset": 49.482721556994996,
#     "x": -0.994,
#     "y": -0.017,
#     "z": -0.051000000000000004,
#     "timelapse": "False",
#     "filename": "4ed5dc9e-f875-4df7-92d7-123d5e44f958.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1851
# Message Key: 2d11e145b0ea48f795622e6cae95ed88
# Message Value:
#   {
#     "id": "f3134b3497ad6a52204ba8419d9000c5",
#     "ride_id": "4611efd78aae450b1a506d67c4b71c17",
#     "uuid": "9c8f3a88bdab444c92a4c7aab083704a",
#     "timestamp": "1970-01-01 00:25:03.758612",
#     "offset": 49.47128348917131,
#     "x": 0.966,
#     "y": -0.009000000000000001,
#     "z": 0.024,
#     "timelapse": "False",
#     "filename": "be49d159-d750-4191-aba8-fa72218a78ca.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1852
# Message Key: 3db0a5830df14591825f789f844a099e
# Message Value:
#   {
#     "id": null,
#     "ride_id": "582d3e7fa3cc301af55d6cb6bf20de0c",
#     "uuid": "35a1f553cfa849bbaec122df745c9457",
#     "timestamp": "1970-01-01 00:24:50.662690",
#     "offset": 49.47898862018564,
#     "x": -0.995,
#     "y": 0.021,
#     "z": -0.03,
#     "timelapse": "False",
#     "filename": "e9ac52ac-7ccd-48a5-af60-7bdd8c53ac9f.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1853
# Message Key: 8ec5803057834f589d24011f4e29e3e2
# Message Value:
#   {
#     "id": "723d9d0fa092b5ca1ffce252012836de",
#     "ride_id": "4f9ca8ae06a03858267820b3ad458fce",
#     "uuid": "459eeb9143d04df3b27397678047be20",
#     "timestamp": "1970-01-01 00:25:04.355827",
#     "offset": 49.47424503805739,
#     "x": -1.0090000000000001,
#     "y": 0.012,
#     "z": -0.033,
#     "timelapse": "False",
#     "filename": "78665bfb-b7d8-464a-a840-8a967d44e187.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1854
# Message Key: 034b2c237769404f94bac41f7ecdbba8
# Message Value:
#   {
#     "id": "3b4793accf1f5feb077f7c8e097642a7",
#     "ride_id": "5205b643b19fddd587541333533b2d4a",
#     "uuid": "f547f4bf60cb40d3a86e00412d076e18",
#     "timestamp": "1970-01-01 00:25:07.471335",
#     "offset": 49.476917343641766,
#     "x": 1.056,
#     "y": -0.032,
#     "z": -0.034,
#     "timelapse": "False",
#     "filename": "3fd49753-bc3e-401c-8511-bcb79223cc6b.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1855
# Message Key: 977c301485c74ae98ef8e892cf6ed86a
# Message Value:
#   {
#     "id": null,
#     "ride_id": "b1df722f6aa469b416e6abb65c5f7fc4",
#     "uuid": "04661f25e6354f5b92284e804a97db95",
#     "timestamp": "1970-01-01 00:24:50.304814",
#     "offset": 50.222265911965,
#     "x": 1.1420000000000001,
#     "y": -0.068,
#     "z": -0.137,
#     "timelapse": "False",
#     "filename": "57d21f3f-97c6-45b1-89f8-8ddc0ce78b48.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 1856
# Message Key: 99342171c60b40818b35b0feff5cee15
# Message Value:
#   {
#     "id": null,
#     "ride_id": "582c5336938f138cf286af1adc12e3b3",
#     "uuid": "88005d17b10e4fcb8dec1cff5627ad39",
#     "timestamp": "1970-01-01 00:24:50.293780",
#     "offset": 49.47038790226978,
#     "x": -0.9570000000000001,
#     "y": -0.001,
#     "z": -0.176,
#     "timelapse": "False",
#     "filename": "a96b2581-610e-441f-9fdd-ed004ba41d27.mov"
#   }
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 1826
# Message Key: baa21414547a4a49b88bd4988c62945d
# Message Value:
#   {
#     "id": "097ec0c2d59a23b76b4942bd8d9a7a77",
#     "ride_id": "9cd83b5a569a73d2e596888b6a6ad6ad",
#     "uuid": "a8fab740fe074ef1acc7d4c940398ce8",
#     "timestamp": "1970-01-01 00:25:04.070061",
#     "offset": 53.16329633059419,
#     "course": 317.4609375,
#     "latitude": 37.523430464824216,
#     "longitude": -122.2665801645464,
#     "geohash": "9q9j3ybjy4mv",
#     "speed": 27.299999237060547,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "65c58848-8a31-4b1c-bfef-8643378fec25.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 1827
# Message Key: 8781b226c29447259256c68c81266652
# Message Value:
#   {
#     "id": "6edc87cd82b135715d4581c2505ef753",
#     "ride_id": "a19ba1f168154326694b7dbc2209518f",
#     "uuid": "1bb324e027224f769047ac3a76afeb5c",
#     "timestamp": "1970-01-01 00:25:04.016744",
#     "offset": 53.14548352122478,
#     "course": 84.7265625,
#     "latitude": 40.7663436234377,
# ...
#     "filename": "dd9fe4fb-fbe6-4b84-a8d8-430c991d5888.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 2158
# Message Key: 69289b7f94d04b61a9c4782506634440
# Message Value:
#   {
#     "id": null,
#     "ride_id": "b710d8312757efeb9d4d1dbf0e545653",
#     "uuid": "95ffd0af905a4549bfe975526605e41f",
#     "timestamp": "1970-01-01 00:24:50.489909",
#     "offset": 113.9271214096826,
#     "course": 296.87286376953125,
#     "latitude": 37.8047795801069,
#     "longitude": -122.27236081971458,
#     "geohash": "9q9p1d5uz3xw",
#     "speed": 2.4200000762939453,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "faa2aa67-b813-4d82-a1e1-4e308be8086d.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 2159
# Message Key: 0115131f5fb9484e9840f759621ea5cf
# Message Value:
#   {
#     "id": "4a7bf56df03b1db624c2813b6b94dfda",
#     "ride_id": "3b210670ccfce98e494c10d1c5a70ca7",
#     "uuid": "d1f37820e0e842069d59649cae7cd0ef",
#     "timestamp": "1970-01-01 00:25:07.065378",
#     "offset": 113.42032814760898,
#     "course": 271.3053894042969,
#     "latitude": 40.92332673621211,
#     "longitude": -73.85810246775353,
#     "geohash": "dr72z3f5tmp0",
#     "speed": 8.140000343322754,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "92d1b741-3093-4991-9b35-ba406aa55d78.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 2160
# Message Key: 5368059f4b8446f7bc5d37aab7492fc0
# Message Value:
#   {
#     "id": "193ec33b0d4330452d8e6214388efbe6",
#     "ride_id": "7758b047316155c7991ceddfcb964f96",
#     "uuid": "6cfaa4a137fc419199221719e2b34aae",
#     "timestamp": "1970-01-01 00:25:03.500112",
#     "offset": 114.16689596075452,
#     "course": 200.0390625,
#     "latitude": 40.681958142705895,
#     "longitude": -74.00250999263861,
#     "geohash": "dr5rkjcj8d9j",
#     "speed": 19.8799991607666,
#     "accuracy": 5.0,
#     "timelapse": "False",
#     "filename": "ef07c198-5de5-430f-b648-632c762c7b3a.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 2161
# Message Key: ba906745ef3f4fbfa5d02358a68ed59c
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256858",
#     "offset": 113.44092680518744,
#     "course": 177.26060485839844,
#     "latitude": 32.172214976075146,
#     "longitude": 34.893385622753435,
#     "geohash": "sv8z40b8dzd1",
#     "speed": 9.319999694824219,
#     "accuracy": 5.0,
#     "timelapse": "False",
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2199
# Message Key: 2ee25ff81df648b1b93a37fa968779c5
# Message Value:
#   {
#     "id": "6c80ca6e1ef9bdb82d6c76f24628170f",
#     "ride_id": "c0de51787e2ccff7b6a9c487bb8928e4",
#     "uuid": "59e5c1c722e24261bbf3bbca3b7e7296",
#     "timestamp": "1970-01-01 00:25:06.894678",
#     "offset": 113.186956897021,
#     "x": -0.9470000000000001,
#     "y": -0.019,
#     "z": -0.183,
#     "timelapse": "False",
#     "filename": "dd9fe4fb-fbe6-4b84-a8d8-430c991d5888.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2200
# Message Key: 6b107f150bd5414199e42ad2ac7042ea
# Message Value:
#   {
#     "id": null,
#     "ride_id": "b710d8312757efeb9d4d1dbf0e545653",
#     "uuid": "95ffd0af905a4549bfe975526605e41f",
#     "timestamp": "1970-01-01 00:24:50.489909",
#     "offset": 113.1811214096826,
#     "x": 0.93,
#     "y": -0.007,
#     "z": 0.23500000000000001,
#     "timelapse": "False",
#     "filename": "faa2aa67-b813-4d82-a1e1-4e308be8086d.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2201
# Message Key: 8dc8445dedc1444480b7fbae3a8a9625
# Message Value:
#   {
#     "id": "4a7bf56df03b1db624c2813b6b94dfda",
#     "ride_id": "3b210670ccfce98e494c10d1c5a70ca7",
#     "uuid": "d1f37820e0e842069d59649cae7cd0ef",
#     "timestamp": "1970-01-01 00:25:07.065378",
#     "offset": 113.18232814760898,
#     "x": -0.99,
#     "y": -0.075,
#     "z": -0.01,
#     "timelapse": "False",
#     "filename": "92d1b741-3093-4991-9b35-ba406aa55d78.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2202
# Message Key: bacf65246246451aa78c6e41a0ce9bd4
# Message Value:
#   {
#     "id": "193ec33b0d4330452d8e6214388efbe6",
#     "ride_id": "7758b047316155c7991ceddfcb964f96",
#     "uuid": "6cfaa4a137fc419199221719e2b34aae",
#     "timestamp": "1970-01-01 00:25:03.500112",
#     "offset": 113.18189596075452,
#     "x": -1.002,
#     "y": 0.047,
#     "z": 0.062,
#     "timelapse": "False",
#     "filename": "ef07c198-5de5-430f-b648-632c762c7b3a.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2203
# Message Key: 2dc31230dc154479bb0be6db2664f4cb
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256858",
#     "offset": 113.18592680518745,
#     "x": -0.999,
#     "y": -0.299,
#     "z": 0.121,
#     "timelapse": "False",
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2204
# Message Key: 8b1a270e0d9a48baa71d088f67854bb8
# Message Value:
#   {
#     "id": null,
#     "ride_id": "6a82f54b23e0e72d9113b5e22bd51706",
#     "uuid": "8f8b11cb622b42e0a2ed985c9df49f62",
#     "timestamp": "1970-01-01 00:24:50.561153",
#     "offset": 113.1976808864028,
#     "x": 0.986,
#     "y": 0.045,
#     "z": 0.334,
#     "timelapse": "False",
#     "filename": "b531ecfa-41ab-4f34-baeb-c6e0efbd962a.mov"
#   }
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 2162
# Message Key: d5b7f1945a0742ce91cc4bbc5a92072e
# Message Value:
#   {
#     "id": "6c80ca6e1ef9bdb82d6c76f24628170f",
#     "ride_id": "c0de51787e2ccff7b6a9c487bb8928e4",
#     "uuid": "59e5c1c722e24261bbf3bbca3b7e7296",
#     "timestamp": "1970-01-01 00:25:06.894674",
#     "offset": 117.424956897021,
#     "course": 259.453125,
#     "latitude": 40.6882034568495,
#     "longitude": -73.94643740735384,
#     "geohash": "dr5rmr1cgngg",
#     "speed": 7.889999866485596,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "dd9fe4fb-fbe6-4b84-a8d8-430c991d5888.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 2163
# Message Key: a3871d10190e416b87f2104907e8d6f3
# Message Value:
#   {
#     "id": null,
#     "ride_id": "b710d8312757efeb9d4d1dbf0e545653",
#     "uuid": "95ffd0af905a4549bfe975526605e41f",
#     "timestamp": "1970-01-01 00:24:50.489905",
#     "offset": 117.9271214096826,
#     "course": 296.87286376953125,
#     "latitude": 37.80475413018826,
#     "longitude": -122.27229752075692,
#     "geohash": "9q9p1dhh8uyy",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "faa2aa67-b813-4d82-a1e1-4e308be8086d.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 2164
# Message Key: 5daaec9e6a9544d790edf080d63127de
# Message Value:
#   {
#     "id": "4a7bf56df03b1db624c2813b6b94dfda",
#     "ride_id": "3b210670ccfce98e494c10d1c5a70ca7",
#     "uuid": "d1f37820e0e842069d59649cae7cd0ef",
#     "timestamp": "1970-01-01 00:25:07.065374",
#     "offset": 117.42032814760898,
#     "course": 271.3053894042969,
#     "latitude": 40.923318462889796,
#     "longitude": -73.85762380835826,
#     "geohash": "dr72z3fe8ekp",
#     "speed": 4.5,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "92d1b741-3093-4991-9b35-ba406aa55d78.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 2165
# Message Key: e04e2c7c3f00483da217a8beeec8bdee
# Message Value:
#   {
#     "id": "193ec33b0d4330452d8e6214388efbe6",
#     "ride_id": "7758b047316155c7991ceddfcb964f96",
#     "uuid": "6cfaa4a137fc419199221719e2b34aae",
#     "timestamp": "1970-01-01 00:25:03.500108",
#     "offset": 118.16689596075452,
#     "course": 199.6875,
#     "latitude": 40.6826159544668,
#     "longitude": -74.00220380171575,
#     "geohash": "dr5rkn11rtm3",
#     "speed": 18.899999618530273,
#     "accuracy": 5.0,
#     "timelapse": "False",
#     "filename": "ef07c198-5de5-430f-b648-632c762c7b3a.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 2166
# Message Key: bbd0ee15965b4a6f8c02a7ddf54ffd8e
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256854",
#     "offset": 117.44092680518744,
#     "course": 173.62954711914062,
#     "latitude": 32.17255112942276,
#     "longitude": 34.893348562903604,
#     "geohash": "sv8z40bd9ynq",
#     "speed": 6.610000133514404,
#     "accuracy": 5.0,
#     "timelapse": "False",
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2205
# Message Key: 98cc2e2a38234f64ad7a9fe519ec4466
# Message Value:
#   {
#     "id": "6c80ca6e1ef9bdb82d6c76f24628170f",
#     "ride_id": "c0de51787e2ccff7b6a9c487bb8928e4",
#     "uuid": "59e5c1c722e24261bbf3bbca3b7e7296",
#     "timestamp": "1970-01-01 00:25:06.894674",
#     "offset": 117.233956897021,
#     "x": -0.992,
#     "y": 0.046,
#     "z": 0.053,
#     "timelapse": "False",
#     "filename": "dd9fe4fb-fbe6-4b84-a8d8-430c991d5888.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2206
# Message Key: c38b07bee13740aab4ffb34fe74f3d59
# Message Value:
#   {
#     "id": null,
#     "ride_id": "b710d8312757efeb9d4d1dbf0e545653",
#     "uuid": "95ffd0af905a4549bfe975526605e41f",
#     "timestamp": "1970-01-01 00:24:50.489905",
#     "offset": 117.23912140968261,
#     "x": 1.002,
#     "y": -0.058,
#     "z": -0.043000000000000003,
#     "timelapse": "False",
#     "filename": "faa2aa67-b813-4d82-a1e1-4e308be8086d.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2207
# Message Key: 73d6141de09e48358b76d908c503534e
# Message Value:
#   {
#     "id": "4a7bf56df03b1db624c2813b6b94dfda",
#     "ride_id": "3b210670ccfce98e494c10d1c5a70ca7",
#     "uuid": "d1f37820e0e842069d59649cae7cd0ef",
#     "timestamp": "1970-01-01 00:25:07.065374",
#     "offset": 117.232328147609,
#     "x": -1.0090000000000001,
#     "y": -0.073,
#     "z": 0.045,
#     "timelapse": "False",
#     "filename": "92d1b741-3093-4991-9b35-ba406aa55d78.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2208
# Message Key: 941d5c0bb54c4e80aaaffa79d6c37fa8
# Message Value:
#   {
#     "id": "193ec33b0d4330452d8e6214388efbe6",
#     "ride_id": "7758b047316155c7991ceddfcb964f96",
#     "uuid": "6cfaa4a137fc419199221719e2b34aae",
#     "timestamp": "1970-01-01 00:25:03.500108",
#     "offset": 117.23389596075452,
#     "x": -0.998,
#     "y": 0.014,
#     "z": -0.015,
#     "timelapse": "False",
#     "filename": "ef07c198-5de5-430f-b648-632c762c7b3a.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2209
# Message Key: 26b70cb7a7d94a02b0c67b6846f43241
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256854",
#     "offset": 117.23192680518746,
#     "x": -0.964,
#     "y": -0.055,
#     "z": -0.12,
#     "timelapse": "False",
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 2167
# Message Key: c43a6dc4c07544848f5ddcb33fbbf175
# Message Value:
#   {
#     "id": null,
#     "ride_id": "b710d8312757efeb9d4d1dbf0e545653",
#     "uuid": "95ffd0af905a4549bfe975526605e41f",
#     "timestamp": "1970-01-01 00:24:50.489901",
#     "offset": 121.9271214096826,
#     "course": 296.87286376953125,
#     "latitude": 37.80475392252679,
#     "longitude": -122.27229700426199,
#     "geohash": "9q9p1dhh8uzj",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": "False",
#     "filename": "faa2aa67-b813-4d82-a1e1-4e308be8086d.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 2168
# Message Key: db8458098c234135be568c3e9654d91a
# Message Value:
#   {
#     "id": "4a7bf56df03b1db624c2813b6b94dfda",
#     "ride_id": "3b210670ccfce98e494c10d1c5a70ca7",
#     "uuid": "d1f37820e0e842069d59649cae7cd0ef",
#     "timestamp": "1970-01-01 00:25:07.065370",
#     "offset": 121.42032814760898,
#     "course": 159.37246704101562,
#     "latitude": 40.92375763187346,
#     "longitude": -73.85772935072961,
#     "geohash": "dr72z3fqnjm7",
#     "speed": 4.570000171661377,
#     "accuracy": 30.0,
#     "timelapse": "False",
#     "filename": "92d1b741-3093-4991-9b35-ba406aa55d78.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 2169
# Message Key: b29c88cb7aad4cdcaa01bccb06b174ee
# Message Value:
#   {
#     "id": "193ec33b0d4330452d8e6214388efbe6",
#     "ride_id": "7758b047316155c7991ceddfcb964f96",
#     "uuid": "6cfaa4a137fc419199221719e2b34aae",
#     "timestamp": "1970-01-01 00:25:03.500104",
#     "offset": 122.16689596075452,
#     "course": 200.0390625,
#     "latitude": 40.68326546814356,
#     "longitude": -74.00189467712678,
#     "geohash": "dr5rkn1mny7g",
#     "speed": 19.049999237060547,
#     "accuracy": 5.0,
#     "timelapse": "False",
#     "filename": "ef07c198-5de5-430f-b648-632c762c7b3a.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-locations
#   Partition: 0
#   Offset: 2170
# Message Key: b725bbffcedb42d39fec2eb361cd41ea
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256850",
#     "offset": 121.44092680518744,
#     "course": 173.62954711914062,
#     "latitude": 32.172733292884644,
#     "longitude": 34.893324650790845,
#     "geohash": "sv8z40bec2ht",
#     "speed": 5.900000095367432,
#     "accuracy": 5.0,
#     "timelapse": "False",
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2210
# Message Key: 8822cd935d0f4507b34e93945b3a9fff
# Message Value:
#   {
#     "id": null,
#     "ride_id": "b710d8312757efeb9d4d1dbf0e545653",
#     "uuid": "95ffd0af905a4549bfe975526605e41f",
#     "timestamp": "1970-01-01 00:24:50.489901",
#     "offset": 121.4161214096826,
#     "x": 1.012,
#     "y": -0.056,
#     "z": -0.063,
#     "timelapse": "False",
#     "filename": "faa2aa67-b813-4d82-a1e1-4e308be8086d.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2211
# Message Key: 9ddfd56ede8044c688ec43246f3f115b
# Message Value:
#   {
#     "id": "4a7bf56df03b1db624c2813b6b94dfda",
#     "ride_id": "3b210670ccfce98e494c10d1c5a70ca7",
#     "uuid": "d1f37820e0e842069d59649cae7cd0ef",
#     "timestamp": "1970-01-01 00:25:07.065370",
#     "offset": 121.40232814760898,
#     "x": -0.967,
#     "y": 0.311,
#     "z": -0.165,
#     "timelapse": "False",
#     "filename": "92d1b741-3093-4991-9b35-ba406aa55d78.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2212
# Message Key: aa3d071d1cb64dcea6bb1dcc8def40c7
# Message Value:
#   {
#     "id": "193ec33b0d4330452d8e6214388efbe6",
#     "ride_id": "7758b047316155c7991ceddfcb964f96",
#     "uuid": "6cfaa4a137fc419199221719e2b34aae",
#     "timestamp": "1970-01-01 00:25:03.500104",
#     "offset": 121.40689596075453,
#     "x": -1.043,
#     "y": 0.066,
#     "z": -0.082,
#     "timelapse": "False",
#     "filename": "ef07c198-5de5-430f-b648-632c762c7b3a.mov"
#   }
#
# Message metadata:
#   Topic: MorrisKyle-accelerations
#   Partition: 0
#   Offset: 2213
# Message Key: 69e614ed4d1c4ebfaf04bc1f89a54583
# Message Value:
#   {
#     "id": "064184d44429da1967d8b2873d6c5053",
#     "ride_id": "6974a887428b102c9564dbcc41b52df0",
#     "uuid": "f57cdc42893d4cbc8b139c1e1650482f",
#     "timestamp": "1970-01-01 00:25:04.256850",
#     "offset": 121.41792680518745,
#     "x": -1.054,
#     "y": -0.138,
#     "z": 0.031,
#     "timelapse": "False",
#     "filename": "e85b702f-9912-4899-9e10-ccd89606f089.mov"
#   }
# STOPPING MESSAGE CONSUMER

# %% [markdown]
# Close the consumer, waiting indefinitely for any needed cleanup.

# %%
consumer.close()
